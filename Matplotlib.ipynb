# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.arange(4,10)
y =np.arange(1,7)

# %%
# 1.) Scatter Plot

# %%
plt.scatter(x,y,c="b")
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Scatter plot in 2d")
plt.savefig("Test.png")

# %%
plt.scatter(x,y,c="b")

# %%
## Line

# %%
plt.plot(x,y,"r")

# %%
plt.plot(x,y*y,"y")

# %%
plt.plot(x,y*y,"y--")

# %%
plt.plot(x,y*y,"go")

# %%
plt.plot(x,y*y,"g*--",linewidth =10,markersize=20)

# %%
plt.plot(x,y*y,"go--")

# %%
#### Creating Subplots

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"r")
plt.subplot(2,2,2)
plt.plot(x,y,"g*--")
plt.subplot(2,2,3)
plt.plot(x,y,"y*")
plt.subplot(2,2,4)
plt.plot(x,y,"b--")

# %%
np.pi
4*np.pi
# Out:
# 12.566370614359172

# %%
x = np.arange(1,4*np.pi,0.1)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title("Sine Wave")
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
x = np.arange(1,4*np.pi,0.1)
y = np.cos(x)

# %%
plt.plot(x,y,"r--")
plt.title("Coss Wave")
# Out:
# Text(0.5, 1.0, 'Coss Wave')

# %% [markdown]
# ### 3.) Barplot

# %%
x = [2,8,10]
y= [11,16,9]
plt.bar(x,y,color = "r")
# Out:
# <BarContainer object of 3 artists>

# %%
x = [2,8,10]
y= [11,16,9]
plt.bar(x,y,color = "r")
x1 =[ 3,9,11]
y1= [6,15,7]
plt.bar(x1,y1,color = "g")
plt.title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %% [markdown]
# #### 4.) Histograms

# %%
a  = np.array([23,45,68,12,44,6,9,23,71,89,10,3,4,78,66,23,45,95])

# %%
plt.hist(a,bins =10)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# #### 5 .) Boxplot

# %%
data = a  = np.array([23,45,68,12,44,6,9,23,71,89,10,3,4,78,66,23,45,95])

# %%
plt.boxplot(data)
plt.title("Box Plot")
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
data = a  = np.array([23,45,68,12,44,6,9,23,71,89,10,3,4,78,66,23,45,95,500,600])

# %%
plt.boxplot(data)
plt.title("Box Plot")
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
plt.boxplot(data, vert=False, patch_artist =True)
plt.title("Box Plot")
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %% [markdown]
# #### 4.) Pie Chart

# %%
labels = ["Python","C++","Ruby","Java"]

data = [216,200,100,270]

explode = (0.4,0,0,0)
colors = ["Red","Green","Blue","Yellow",

# %%
plt.pie(data,explode=explode,colors= colors,labels =labels,shadow =True )
# Out:
# ([<matplotlib.patches.Wedge at 0x1e063e1b130>,
# ...
#  [Text(0.9748557688724164, 1.1400246619684025, 'Python'),
#   Text(-0.898115300286898, 0.6351290478245939, 'C++'),
#   Text(-0.917961460688959, -0.606091376518255, 'Ruby'),
#   Text(0.5192631659281818, -0.9697245817809517, 'Java')])
